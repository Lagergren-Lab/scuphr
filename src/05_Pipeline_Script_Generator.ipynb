# %% [markdown]
# # 05. Pipeline Script Generator
#
# This notebook automatically generates needed scripts for the cluster. The scripts are Uppmax-compatible, it loads modules such as bioinfo-tools, pysam, samtools etc. Further modifications are needed to be done for Tetralith compatibility (such as activating a Conda environment).
#
# Steps:
# * Generate scripts (pipeline_scripts.py)
#
# For Tetralith:
# * Remove #SBATCH -p core line
# * Remove module load python3
# * Add module load Python/3.7.0-anaconda-5.3.0-extras-nsc1
# * Add source activate /proj/sc_ml/users/x_hazko/scuphr_conda/scuphr_env (or another conda environment)
# * Also, the number of allocated cores can be increased.

# %%
# %run pipeline_scripts.py --help
# Out:
# usage: pipeline_scripts.py [-h] [--chr_id CHR_ID] [--data_type DATA_TYPE]
#                            [--global_dir GLOBAL_DIR] [--num_cells NUM_CELLS]
#                            [--output_dir OUTPUT_DIR] [--p_ado P_ADO]
#                            [--p_ae P_AE] [--pos_range_min POS_RANGE_MIN]
#                            [--pos_range_max POS_RANGE_MAX]
#                            [--print_status PRINT_STATUS]
#                            [--read_length READ_LENGTH] [--seed_val SEED_VAL]
#                            [--ado_poisson_rate ADO_POISSON_RATE]
#                            [--ado_type ADO_TYPE] [--amp_method AMP_METHOD]
#                            [--genome_length GENOME_LENGTH]
#                            [--gsnv_rate GSNV_RATE] [--is_flat IS_FLAT]
#                            [--mut_poisson_rate MUT_POISSON_RATE]
#                            [--num_iter NUM_ITER]
#                            [--num_max_mid_points NUM_MAX_MID_POINTS]
#                            [--num_rep_amp_bias NUM_REP_AMP_BIAS]
#                            [--phred_type PHRED_TYPE]
#                            [--bulk_depth_threshold BULK_DEPTH_THRESHOLD]
#                            [--cell_depth_threshold CELL_DEPTH_THRESHOLD]
#                            [--het_ratio_threshold HET_RATIO_THRESHOLD]
#                            [--min_line MIN_LINE] [--max_line MAX_LINE]
#                            [--nuc_depth_threshold NUC_DEPTH_THRESHOLD]
#                            [--min_read_count MIN_READ_COUNT]
#                            [--max_read_count MAX_READ_COUNT]
#                            [--min_cell_count MIN_CELL_COUNT]
#                            [--output_dict_dir OUTPUT_DICT_DIR] [--a_g A_G]
#                            [--b_g B_G]
#                            project_name project_dir
#
# Generate scripts for the pipeline.
#
# positional arguments:
#   project_name          Specify the project name. Needed for -A tag in bash
#                         script.
#   project_dir           Specify the source code directory, i.e. /proj/scuphr/
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --chr_id CHR_ID       Specify the chromosome number. Default: 1
#   --data_type DATA_TYPE
#                         Specify the data type. Default: real
#   --global_dir GLOBAL_DIR
#                         Specify the directory.
#   --num_cells NUM_CELLS
#                         Specify the number of cells. Default: 10
#   --output_dir OUTPUT_DIR
#                         Specify the output directory.
#   --p_ado P_ADO         Specify the allelic dropout probability of a base.
#                         Default: 0.005
#   --p_ae P_AE           Specify the amplification error probability of a base.
#                         Default: 0.00001
#   --pos_range_min POS_RANGE_MIN
#                         Specify the position range (min value).
#   --pos_range_max POS_RANGE_MAX
#                         Specify the position range (max value).
#   --print_status PRINT_STATUS
#                         Specify the print (0 for do not print, 1 for print).
#                         Default: 0
#   --read_length READ_LENGTH
#                         Specify the read length. Default: 100
#   --seed_val SEED_VAL   Specify the seed. Default: 123
#   --ado_poisson_rate ADO_POISSON_RATE
#                         Specify the ado poisson rate. Default: 0
#   --ado_type ADO_TYPE   Specify the allelic dropout type (0 for no ado, 1 for
#                         random Beta, 2 for even smaller Beta, 3 for fixed.
#                         Default: 3).
#   --amp_method AMP_METHOD
#                         Specify the amplification method. Default: mda
#   --genome_length GENOME_LENGTH
#                         Specify the length of genome. Default: 50000
#   --gsnv_rate GSNV_RATE
#                         Specify the gSNV rate. Default: 0.005
#   --is_flat IS_FLAT     Specify the amplification bias type (True for flat,
#                         False for sine wave). Default: False
#   --mut_poisson_rate MUT_POISSON_RATE
#                         Specify the mutation poisson rate. Default: 3
#   --num_iter NUM_ITER   Specify the number of iteration. Default: 5000
#   --num_max_mid_points NUM_MAX_MID_POINTS
#                         Specify the number of division points of amplification
#                         bias. Default: 10
#   --num_rep_amp_bias NUM_REP_AMP_BIAS
#                         Specify the number of repetitions of amplification
#                         bias. Default: 3
#   --phred_type PHRED_TYPE
#                         Specify the phred score type (0 for no errors, 1 for
#                         all 42, 2 for truncated normal). Default: 2
#   --bulk_depth_threshold BULK_DEPTH_THRESHOLD
#                         Specify the bulk depth threshold. Default: 20
#   --cell_depth_threshold CELL_DEPTH_THRESHOLD
#                         Specify the cell depth threshold. Default: 0
#   --het_ratio_threshold HET_RATIO_THRESHOLD
#                         Specify the bulk heterozygous ratio threshold.
#                         Default: 0.2
#   --min_line MIN_LINE   Specify the line number of min het position. Default:
#                         0
#   --max_line MAX_LINE   Specify the line number of max het position. Default:
#                         0
#   --nuc_depth_threshold NUC_DEPTH_THRESHOLD
#                         Specify the minimum number of valid reads. Default: 2
#   --min_read_count MIN_READ_COUNT
#                         Specify the minimum read count. Default: 0
#   --max_read_count MAX_READ_COUNT
#                         Specify the maximum read count (0 for all). Default: 0
#   --min_cell_count MIN_CELL_COUNT
#                         Specify the minimum cell count. Default: 2
#   --output_dict_dir OUTPUT_DICT_DIR
#                         Specify the output dictionary directory.
#   --a_g A_G             Specify the alpha prior of mutation probability.
#                         Default: 1
#   --b_g B_G             Specify the beta prior of mutation probability.
#                         Default: 1

# %%
# %run pipeline_scripts.py snic2020-5-278 ../ --num_cells 5 --genome_length 20000 --data_type synthetic --global_dir example_dataset/ --output_dir example_results/
# Out:
# Create necessary folders
#
# Get all parameters
#
# Writing data simulation script
#
# Script is saved to  ../data/example_dataset/scripts/script_01_data_simulation.sh
#
# Writing site detection par script
#
# Script is saved to  ../data/example_dataset/scripts/script_02_site_detection.sh
#
# Writing generate dataset script
#
# Script is saved to  ../data/example_dataset/scripts/script_03_generate_dataset.sh
#
# Writing distance between cells script
#
# Script is saved to  ../results/example_results/scripts/script_04_dbc.sh
#
# Writing distance between cells combine script
#
# Script is saved to  ../results/example_results/scripts/script_05_dbc_combine.sh
#
# Writing lineage tree script
#
# Script is saved to  ../results/example_results/scripts/script_06_lineage_tree.sh
#
# Writing combined data par simulation script
#
# Script is saved to  ../data/example_dataset/scripts/script_00_combined_data_par.sh

# %% [markdown]
# ## Example Usage
#
# Below is the pipeline script generator. I generated a small dataset. Then, in the following cells in this notebook, I ran the generated commands in the scripts one by one. Normally, one needs to submit jobs in the cluster one by one.

# %%
# %run pipeline_scripts.py snic2020-5-278 ../ --data_type synthetic --global_dir 2020_07_09/ --genome_length 10000 --seed_val 42 --num_cells 5 --num_iter 1000 --p_ado 0.3 --ado_poisson_rate 100 --p_ae 0.00002 --max_read_count 10 --output_dir 2020_07_09_results/
# Out:
# Create necessary folders
#
# Get all parameters
#
# Writing data simulation script
#
# Script is saved to  ../data/2020_07_09/scripts/script_01_data_simulation.sh
#
# Writing site detection par script
#
# Script is saved to  ../data/2020_07_09/scripts/script_02_site_detection.sh
#
# Writing generate dataset script
#
# Script is saved to  ../data/2020_07_09/scripts/script_03_generate_dataset.sh
#
# Writing distance between cells script
#
# Script is saved to  ../results/2020_07_09_results/scripts/script_04_dbc.sh
#
# Writing distance between cells combine script
#
# Script is saved to  ../results/2020_07_09_results/scripts/script_05_dbc_combine.sh
#
# Writing lineage tree script
#
# Script is saved to  ../results/2020_07_09_results/scripts/script_06_lineage_tree.sh
#
# Writing combined data par simulation script
#
# Script is saved to  ../data/2020_07_09/scripts/script_00_combined_data_par.sh

# %% [markdown]
# ### Simulate Data

# %%
# %run data_simulator.py  --seed_val 42 --p_ae 2e-05 --num_max_mid_points 10 --ado_poisson_rate 100.0 --phred_type 2 --chr_id 1 --mut_poisson_rate 3 --is_flat False --num_iter 1000 --p_ado 0.3 --amp_method mda --num_rep_amp_bias 3 --num_cells 5 --global_dir ../data/2020_07_09/ --read_length 100 --gsnv_rate 0.005 --ado_type 3 --genome_length 10000
# Out:
# The data directory:  ../data/2020_07_09/
#
# Part 0: Save arguments
#
#
# Total time:  0.0007112026214599609
# Part 0 ends...
#
# Data simulation starts...
#
# Part 1: Amplification bias
#
# 	Middle points for repetition  0 :  [ 466  860 4426 5191 5390 5734 6265]
# 	Middle points for repetition  1 :  [2064 2303 3392 7985 8499]
# 	Middle points for repetition  2 :  [ 571 2144 3491 3971 9389]
#
# Total time:  0.37949180603027344
# Part 1 ends...
#
# Part 2: Reference, bulk and mutation generation
#
# 	numBp:  10000
# 	gSNV count:  50
# 	mutation count:  250
# 	Total gSNV count:  50 	Total mutation count:  250 	Mutations close to a gSNV:  126
# 	Running:  samtools view ../data/2020_07_09/bulk_ref.sam | awk '{OFS="\t"; print ">"$1"\n"$10}' - > ../data/2020_07_09/bulk_ref.fasta
# 	Running:  samtools view -h -b -S ../data/2020_07_09/bulk.sam > ../data/2020_07_09/bulk.bam
# 	Running:  samtools index -b ../data/2020_07_09/bulk.bam
#
# Total time:  1.726686954498291
# Part 1 ends...
#
# Part 3: Tree generation and mutation partition
#
# 	parent nodes:  [0 0 0 1 1 2 2 5 5]
# 	leaf nodes:  [3, 4, 6, 7, 8]
#
# Total time:  0.0024771690368652344
# Part 3 ends...
#
# Part 4: Cell simulation
#
#
# 	Simulating cell:  0
#
# 	Number of Mutations:  58
#
# 	Total time for cell's generateCellGenotype:  0.0009431838989257812
# 	p_ado:  0.3
# 	Number of mask events:  63
# 		Number of covered basepairs:  6327
# 		Mask information:  {128: 1, 80: 1, 56: 1, 83: 2, 85: 2, 86: 1, 87: 1, 88: 2, 90: 1, 91: 1, 92: 5, 93: 2, 94: 2, 95: 2, 96: 1, 99: 2, 100: 3, 101: 2, 102: 4, 104: 7, 105: 1, 106: 2, 107: 1, 109: 3, 110: 1, 111: 3, 112: 1, 113: 1, 115: 1, 116: 1, 117: 2, 118: 1, 119: 1, 120: 1}
#
# 	Total time for cell's maskGenome:  0.004021883010864258
#
# 	Total time for cell's amplifyGenome:  0.9362664222717285 0.1517953872680664 0.7844710350036621 0.7671377658843994
# 	Number of rejected fragments due to amplification wave:  6470
#
# 	Total number of fragments:  790
# 		Number of fragments without amplification error:  648
# 		Number of amplification errors:  14
# 		Number of fragments with amplification error:  13
# 		Number of fragments with amplification error (inherited from another fragment):  129
# 		Number of fragments originated from other fragments:  732
#
# 	Total time for cell's amplifyGenome:  1.0116760730743408
#
# 	New number of fragments (reads):  3450
# 		Number of masked fragments:  2937
#
# 	Total time for cell's cutFragments:  0.1982588768005371
#
# 	Total number of bases in reads:  345000
# 	Total number of bases with amplification error:  842
# 	Amplification error per read base ratio:  0.0024405797101449277
#
# 	Approximate cell coverage:  34.5
#
# 	Total time for cell's ampErrorCount:  0.021262168884277344
#
# 	Total time for cell's generateReads:  16.229557037353516 4.2105937004089355 12.01896333694458 10.93556523323059
#
# 	Total time generateReads subsets:  4.124113321304321 0.08089065551757812
#
# 	Number of sequencing errors:  95
#
# 	Total time for cell's generateReads:  16.242316961288452
# 	Running:  samtools view -h -b -S ../data/2020_07_09/cell_idx_0.sam > ../data/2020_07_09/cell_idx_0.bam
# 	Running:  samtools index -b ../data/2020_07_09/cell_idx_0.bam
#
# 	Total time for cell's generateCellSam:  0.263059139251709
#
# 	Total time for cell :  17.742071866989136
#
# 	Simulating cell:  1
#
# 	Number of Mutations:  70
#
# 	Total time for cell's generateCellGenotype:  0.0006117820739746094
# 	p_ado:  0.3
# 	Number of mask events:  54
# 		Number of covered basepairs:  5286
# 		Mask information:  {77: 1, 82: 1, 84: 2, 85: 1, 86: 2, 88: 5, 89: 1, 92: 2, 93: 2, 94: 3, 95: 1, 96: 3, 97: 2, 98: 4, 99: 3, 101: 3, 102: 2, 103: 2, 104: 1, 106: 4, 107: 1, 109: 2, 111: 1, 112: 2, 113: 1, 115: 1, 126: 1}
#
# 	Total time for cell's maskGenome:  0.0022537708282470703
#
# 	Total time for cell's amplifyGenome:  0.8528659343719482 0.11234140396118164 0.7405245304107666 0.7290067672729492
# 	Number of rejected fragments due to amplification wave:  6844
#
# 	Total number of fragments:  796
# 		Number of fragments without amplification error:  645
# 		Number of amplification errors:  8
# 		Number of fragments with amplification error:  8
# 		Number of fragments with amplification error (inherited from another fragment):  143
# 		Number of fragments originated from other fragments:  739
#
# 	Total time for cell's amplifyGenome:  0.9069831371307373
#
# 	New number of fragments (reads):  4172
# 		Number of masked fragments:  3262
#
# 	Total time for cell's cutFragments:  0.1870419979095459
#
# 	Total number of bases in reads:  417200
# 	Total number of bases with amplification error:  614
# 	Amplification error per read base ratio:  0.0014717162032598275
#
# 	Approximate cell coverage:  41.72
#
# 	Total time for cell's ampErrorCount:  0.0230410099029541
#
# 	Total time for cell's generateReads:  17.595046043395996 4.5717620849609375 13.023283958435059 11.881494998931885
#
# 	Total time generateReads subsets:  4.4829864501953125 0.08363699913024902
#
# 	Number of sequencing errors:  120
#
# 	Total time for cell's generateReads:  17.620057821273804
# 	Running:  samtools view -h -b -S ../data/2020_07_09/cell_idx_1.sam > ../data/2020_07_09/cell_idx_1.bam
# 	Running:  samtools index -b ../data/2020_07_09/cell_idx_1.bam
#
# 	Total time for cell's generateCellSam:  0.305042028427124
#
# 	Total time for cell :  19.045221090316772
#
# 	Simulating cell:  2
#
# 	Number of Mutations:  58
#
# 	Total time for cell's generateCellGenotype:  0.0006129741668701172
# 	p_ado:  0.3
# 	Number of mask events:  65
# 		Number of covered basepairs:  6577
# 		Mask information:  {136: 1, 79: 1, 80: 2, 82: 1, 86: 2, 87: 1, 90: 1, 91: 2, 92: 3, 93: 4, 94: 2, 95: 3, 96: 4, 97: 2, 98: 1, 99: 1, 100: 3, 101: 1, 103: 3, 104: 4, 105: 2, 106: 1, 107: 3, 109: 3, 110: 2, 111: 2, 112: 1, 113: 1, 114: 2, 116: 2, 117: 1, 118: 2, 123: 1}
#
# 	Total time for cell's maskGenome:  0.0018229484558105469
#
# 	Total time for cell's amplifyGenome:  0.652517557144165 0.09779524803161621 0.5547223091125488 0.5444943904876709
# 	Number of rejected fragments due to amplification wave:  6317
#
# 	Total number of fragments:  793
# 		Number of fragments without amplification error:  781
# 		Number of amplification errors:  7
# 		Number of fragments with amplification error:  7
# 		Number of fragments with amplification error (inherited from another fragment):  5
# 		Number of fragments originated from other fragments:  726
#
# 	Total time for cell's amplifyGenome:  0.6999809741973877
#
# 	New number of fragments (reads):  2840
# 		Number of masked fragments:  3344
#
# 	Total time for cell's cutFragments:  0.12699580192565918
#
# 	Total number of bases in reads:  284000
# 	Total number of bases with amplification error:  248
# 	Amplification error per read base ratio:  0.0008732394366197183
#
# 	Approximate cell coverage:  28.4
#
# 	Total time for cell's ampErrorCount:  0.01710796356201172
#
# 	Total time for cell's generateReads:  14.555234670639038 3.823009729385376 10.732224941253662 9.747466087341309
#
# 	Total time generateReads subsets:  3.734945297241211 0.08354735374450684
#
# 	Number of sequencing errors:  94
#
# 	Total time for cell's generateReads:  14.584752082824707
# 	Running:  samtools view -h -b -S ../data/2020_07_09/cell_idx_2.sam > ../data/2020_07_09/cell_idx_2.bam
# 	Running:  samtools index -b ../data/2020_07_09/cell_idx_2.bam
#
# 	Total time for cell's generateCellSam:  0.3115711212158203
#
# 	Total time for cell :  15.743005990982056
#
# 	Simulating cell:  3
#
# 	Number of Mutations:  95
#
# 	Total time for cell's generateCellGenotype:  0.0006299018859863281
# 	p_ado:  0.3
# 	Number of mask events:  58
# 		Number of covered basepairs:  6007
# 		Mask information:  {86: 1, 89: 1, 90: 1, 91: 1, 92: 1, 93: 2, 94: 2, 95: 1, 96: 3, 97: 1, 98: 2, 99: 2, 100: 3, 101: 4, 102: 4, 103: 1, 104: 5, 105: 3, 106: 2, 107: 2, 108: 2, 109: 3, 111: 3, 112: 1, 113: 1, 115: 1, 119: 1, 124: 1, 125: 2, 126: 1}
#
# 	Total time for cell's maskGenome:  0.0021500587463378906
#
# 	Total time for cell's amplifyGenome:  0.9203774929046631 0.19464492797851562 0.7257325649261475 0.7114315032958984
# 	Number of rejected fragments due to amplification wave:  6676
#
# 	Total number of fragments:  779
# 		Number of fragments without amplification error:  650
# 		Number of amplification errors:  16
# 		Number of fragments with amplification error:  16
# 		Number of fragments with amplification error (inherited from another fragment):  113
# 		Number of fragments originated from other fragments:  718
#
# 	Total time for cell's amplifyGenome:  0.9905338287353516
#
# 	New number of fragments (reads):  3507
# 		Number of masked fragments:  3382
#
# 	Total time for cell's cutFragments:  0.22684597969055176
#
# 	Total number of bases in reads:  350700
# 	Total number of bases with amplification error:  1138
# 	Amplification error per read base ratio:  0.0032449386940404906
#
# 	Approximate cell coverage:  35.07
#
# 	Total time for cell's ampErrorCount:  0.019436120986938477
#
# 	Total time for cell's generateReads:  17.07466220855713 4.435115575790405 12.639546632766724 11.47968602180481
#
# 	Total time generateReads subsets:  4.340879917144775 0.08880877494812012
#
# 	Number of sequencing errors:  102
#
# 	Total time for cell's generateReads:  17.10039210319519
# 	Running:  samtools view -h -b -S ../data/2020_07_09/cell_idx_3.sam > ../data/2020_07_09/cell_idx_3.bam
# 	Running:  samtools index -b ../data/2020_07_09/cell_idx_3.bam
#
# 	Total time for cell's generateCellSam:  0.2946779727935791
#
# 	Total time for cell :  18.635205030441284
#
# 	Simulating cell:  4
#
# 	Number of Mutations:  85
#
# 	Total time for cell's generateCellGenotype:  0.0007069110870361328
# 	p_ado:  0.3
# 	Number of mask events:  63
# 		Number of covered basepairs:  6340
# 		Mask information:  {131: 1, 80: 1, 82: 1, 84: 1, 85: 1, 88: 3, 90: 3, 92: 1, 94: 2, 95: 2, 96: 4, 97: 5, 98: 2, 100: 1, 101: 5, 102: 6, 104: 2, 105: 4, 106: 4, 107: 2, 108: 2, 109: 3, 111: 3, 112: 2, 113: 2}
#
# 	Total time for cell's maskGenome:  0.002343893051147461
#
# 	Total time for cell's amplifyGenome:  0.7442061901092529 0.1188192367553711 0.6253869533538818 0.612999439239502
# 	Number of rejected fragments due to amplification wave:  7300
#
# 	Total number of fragments:  772
# 		Number of fragments without amplification error:  522
# 		Number of amplification errors:  14
# 		Number of fragments with amplification error:  11
# 		Number of fragments with amplification error (inherited from another fragment):  239
# 		Number of fragments originated from other fragments:  707
#
# 	Total time for cell's amplifyGenome:  0.8008110523223877
#
# 	New number of fragments (reads):  3213
# 		Number of masked fragments:  3353
#
# 	Total time for cell's cutFragments:  0.13899493217468262
#
# 	Total number of bases in reads:  321300
# 	Total number of bases with amplification error:  415
# 	Amplification error per read base ratio:  0.0012916277622159974
#
# 	Approximate cell coverage:  32.13
#
# 	Total time for cell's ampErrorCount:  0.013173103332519531
#
# 	Total time for cell's generateReads:  13.080731630325317 3.3785338401794434 9.702197790145874 8.848930358886719
#
# 	Total time generateReads subsets:  3.3149046897888184 0.059851884841918945
#
# 	Number of sequencing errors:  109
#
# 	Total time for cell's generateReads:  13.10185980796814
# 	Running:  samtools view -h -b -S ../data/2020_07_09/cell_idx_4.sam > ../data/2020_07_09/cell_idx_4.bam
# 	Running:  samtools index -b ../data/2020_07_09/cell_idx_4.bam
#
# 	Total time for cell's generateCellSam:  0.2519998550415039
#
# 	Total time for cell :  14.310358047485352
#
# All cell totals
# 	Total number of bases in reads:  1718200
# 	Total number of bases with amplification error:  3257
# 	Amplification error per read base ratio:  0.0018955884064718893
#
# 	Approximate average cell coverages:  34.364
#
# Total time:  85.47597908973694
# Part 4 ends...
#
# Part 5: Relocate files
#
#
# Total time:  0.11164212226867676
# Part 5 ends...
#
# Total (global) time:  87.69863295555115
# Data simulation ends...

# %% [markdown]
# ### Detect Sites

# %%
# %run site_detection.py ../data/2020_07_09/ 5 --seed_val 42  --min_line 0  --print_status 0  --het_ratio_threshold 0.2  --chr_id 1  --nuc_depth_threshold 2  --max_line 0  --bulk_depth_threshold 20  --cell_depth_threshold 0  --read_length 100
# Out:
# Global directory:  ../data/2020_07_09/
#
# *****STEP 1
#
#
# Pair dict is saved to:  ../data/2020_07_09/processed_data/pair_dict.pickle
#
# Pair dict is saved to:  ../data/2020_07_09/processed_data/pair_dict_0_0.pickle
#
# Number of selected pairs:  5
# 	Number of unique het. sites:  6
# 	Number of unique hom. sites:  5
# 	Number of removed duplicate homozygous sites:  1
# 	Total number of pairs:  5
#
# *****
# Total time:  158.24505305290222
#
# *****STEP 2
#
# 	Bulk pairs dictionary is saved to: 	 ../data/2020_07_09/processed_data/bulk_pairs.pickle
# 	Cell pairs dictionary is saved to: 	 ../data/2020_07_09/processed_data/cell_0_pairs.pickle
# 	Cell pairs dictionary is saved to: 	 ../data/2020_07_09/processed_data/cell_1_pairs.pickle
# 	Cell pairs dictionary is saved to: 	 ../data/2020_07_09/processed_data/cell_2_pairs.pickle
# 	Cell pairs dictionary is saved to: 	 ../data/2020_07_09/processed_data/cell_3_pairs.pickle
# 	Cell pairs dictionary is saved to: 	 ../data/2020_07_09/processed_data/cell_4_pairs.pickle
# 	All cell pairs dictionary is saved to: 	 ../data/2020_07_09/processed_data/all_cell_dict_pair.pickle
#
# *****
# Total time:  0.002534151077270508
#
# *****DONE!
#
#
# *****
# Total global time:  158.24768996238708

# %% [markdown]
# ### Generate Dataset

# %%
# %run generate_dataset.py ../data/2020_07_09/ 5 --seed_val 42  --chr_id 1  --data_type synthetic  --min_read_count 0  --output_dict_dir ""  --max_read_count 10  --min_cell_count 2  --read_length 100
# Out:
# Global directory:  ../data/2020_07_09/
# Output directory:  ../data/2020_07_09/processed_data_dict/
#
# Part 1: Load bulk pairs dictionary.
#
# Total time:  0.00018787384033203125
# Part 1 ends...
#
# Part 2: Load cells' pairs dictionaries.
#
#
# Total time:  0.001049041748046875
# Part 2 ends...
#
# Part 3: Generate dataset.
#
# 	Total number of positions:  5
# 	Total number of skipped positions:  0
#
# Total time:  0.014261007308959961
# Part 3 ends...
#
# Part 4: Shuffle and partition the dataset.
#
#
# Shuffle and partition dataset
#
# Shuffled data ( 5 ) is saved to:  ../data/2020_07_09/processed_data_dict/data_shuffled.pickle
# Saving test data ( 2 ) is saved to:  ../data/2020_07_09/processed_data_dict/data_test.pickle
# Saving train data ( 3 ) is saved to:  ../data/2020_07_09/processed_data_dict/data_train.pickle
# Saving shuffled data ( 5 ) is saved to:  ../data/2020_07_09/processed_data_dict/data.pickle
#
# Total time:  0.004559993743896484
# Part 4 ends...
#
# Part 5: Analyse results.
#
# 	Site detection results:
# 	Total number of (real) mutated sites:  250
#
# 	Total number of (real) detectable mutated sites (close to gSNV locations):  126
# 		Number of (real) detectable mutated sites (on internal edges): 	 44
# 		Number of (real) detectable mutated sites (on leaf edges): 	 82
#
# 	Total number of sites correctly detected 	(True Positive): 	 5
# 		Number of mutated sites (detected) (on internal edges): 	 5 	 out of  44 	perc:  11.364
# 		Number of mutated sites (detected) (on leaf edges): 		 0 	 out of  82 	perc:  0.0
# 	Total number of sites incorrectly detected 	(False Positive): 	 0
#
# 	Total number of mutated sites undetected 	(False Negative): 	 121
#
# 	Sensitivity (True positive rate): 	 0.03968253968253968
# 	Precision: 				 1.0
# 	Miss rate (False negative rate): 	 0.9603174603174603
# 	False discovery rate: 			 0.0
# 	F1 score: 				 0.07633587786259542
#
# 	Undetected inner edge mutations:  39
# [80, 88, 259, 416, 1494, 1509, 1593, 2020, 2233, 2344, 2592, 2802, 3393, 3410, 3898, 3912, 4003, 4049, 4081, 4442, 4747, 4751, 4822, 5323, 5741, 5970, 6261, 6442, 6517, 7146, 7417, 7438, 8181, 8446, 8846, 9238, 9335, 9412, 9445]
#
# Total time:  0.0062160491943359375
# Part 5 ends...
#
# All done!
# Total time:  0.026544809341430664

# %% [markdown]
# ### Calculate distance between cells

# %%
# %run analyse_dbc.py ../data/2020_07_09/  --seed_val 42 --p_ae 2e-05 --pos_range_max 0 --b_g 1 --print_status 0 --data_type synthetic --p_ado 0.3 --output_dir ../results/2020_07_09_results/ --pos_range_min 0 --a_g 1
# Out:
# *****
# Load the dataset and read probabilities...
#
# The dataset is loaded. Number of cells: 5, number of position pairs: 5
#
# Position range: [ 0 ,  5 )
# Number of positions in range:  5
#
# *****
# Calculating real distances...
#
# *****
# Calculating real distances finished...
#
# ******
# Analysing Real DBC
# ******
# Analysing Real DBC
# ******
# Analysing Real DBC
# ******
# Analysing Real DBC
#
#
#
# Pos idx of process is:  1
# Pos idx of process is:  0
# Pos idx of process is:  3
# Pos idx of process is:  2
# Process id:  95769 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
# Process id:  95768 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
# Process id:  95771 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
# Process id:  95770 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
#
# ***********
# Position:
# ***********
# Position:
# ***********
# Position:
# ***********
# Position:  1
#  0
#  3
#  2
#
# Total time of position
# Total time of position
# Total time of position
# Total time of position  1  is:  0.028577089309692383
#  0  is:  0.02893686294555664
#  3  is:  0.027788162231445312
#  2  is:  0.034101009368896484
#
# ******
# Analysing Real DBC
# Pos idx of process is:  4
# Process id:  95768 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
#
# ***********
# Position:  4
#
# Total time of position  4  is:  0.00704503059387207
#
# *****
# Calculating inferred distances...
#
# *****
# Calculating inferred distances finished...
#
# ******
# Analysing DBC for parameters:
# ******
# Analysing DBC for parameters:
# ******
# Analysing DBC for parameters:
# ******
# Analysing DBC for parameters:  2e-05 0.3 1.0 1.0
#  2e-05 0.3 1.0 1.0
#  2e-05 0.3 1.0 1.0
#  2e-05 0.3 1.0 1.0
# Pos idx of process is:  0
# Pos idx of process is:  1
# Pos idx of process is:  3
# Pos idx of process is:  2
# Process id:  95772 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
# Process id:  95773 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
# Process id:  95775 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
# Process id:  95774 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
#
# ***********
# Position:
# ***********
# Position:
# ***********
# Position:
# ***********
# Position:  0
#  1
#  3
#  2
#
# Loading read position dictionary...
# Loading read position dictionary...
# Loading read position dictionary...
# Loading read position dictionary...
#
#
#
#
# Loading log_ZCY position dictionary...
# Loading log_ZCY position dictionary...
# Loading log_ZCY position dictionary...
# Loading log_ZCY position dictionary...
#
#
#
# 	Computing for z_ind:  0
# 	Computing for z_ind:  0
# 	Computing for z_ind:  0
# 	Computing for z_ind:  0
# 	Computing for z_ind:  1
# 	Computing for z_ind:  1
# 	Computing for z_ind:  1
# 	Computing for z_ind:  1
# 	Computing for z_ind:  2
# 	Computing for z_ind:  2
# 	Computing for z_ind:  2
# 	Computing for z_ind:  2
# 	Computing for z_ind:  3
# 	Computing for z_ind:  3
# 	Computing for z_ind:  3
# 	Computing for z_ind:  3
# 	Computing for z_ind:  4
# 	Computing for z_ind:  4
# 	Computing for z_ind:  4
# 	Computing for z_ind:  4
# 	Computing for z_ind:  5
# 	Computing for z_ind:  5
# 	Computing for z_ind:  5
# 	Computing for z_ind:  5
# 	Computing for z_ind:  6
# 	Computing for z_ind:  6
# 	Computing for z_ind:  6
# 	Computing for z_ind:  6
# 	Computing for z_ind:  7
# 	Computing for z_ind:  7
# 	Computing for z_ind:  7
# 	Computing for z_ind:  7
# 	Computing for z_ind:  8
# 	Computing for z_ind:  8
# 	Computing for z_ind:  8
# 	Computing for z_ind:  8
# 	Computing for z_ind:  9
# 	Computing for z_ind:  9
# 	Computing for z_ind:  9
# 	Computing for z_ind:  9
# 	Computing for z_ind:  10
# 	Computing for z_ind:  10
# 	Computing for z_ind:  10
# 	Computing for z_ind:  10
# 	Computing for z_ind:  11
# 	Computing for z_ind:  11
# 	Computing for z_ind:  11
# 	Computing for z_ind:  11
# Total time:  0.01813817024230957
# Total time:  0.016216039657592773
# Total time:  0.021708965301513672
# Total time:  0.01826310157775879
#
# ***Common Z results:
#
# ***Common Z results:
#
# ***Common Z results:
#
# ***Common Z results:
#
#
#
#
#
# Normalized probabilities of common mutation type Z:
#
# Normalized probabilities of common mutation type Z:
#
# Normalized probabilities of common mutation type Z:
#
# Normalized probabilities of common mutation type Z:
#  [6.58956756e-11 6.58956756e-11 1.02494378e-10 6.58932812e-11
#  6.65364402e-11 6.58932812e-11 1.02563158e-10 6.59044226e-11
#  6.59044226e-11 1.09836525e-10 9.99999999e-01 1.09836525e-10] [1.03761082e-10 6.67073060e-11 6.67073060e-11 1.11172288e-10
#  9.99999999e-01 1.11172288e-10 6.67072489e-11 6.67072489e-11
#  7.78314701e-11 6.67072487e-11 7.78304595e-11 6.67072487e-11] [1.03815687e-10 6.67318384e-11 6.67318384e-11 6.67284908e-11
#  6.67225415e-11 6.67225415e-11 6.67217046e-11 6.67217046e-11
#  1.03781962e-10 9.99999999e-01 1.11188200e-10 1.11188200e-10] [2.01384837e-07 2.01385086e-07 2.01384837e-07 9.99997328e-01
#  2.41686869e-07 2.41686869e-07 2.41679476e-07 3.76023096e-07
#  2.41679476e-07 2.41690558e-07 2.41676389e-07 2.41676389e-07]
#
#
#
#
# Maximum probability:
# Maximum probability:
# Maximum probability:
# Maximum probability:  0.9999999991133461 . Dict key:  10
#  0.9999999991179886 . Dict key:  4
#  0.9999999991029453 . Dict key:  9
#  0.9999973280461176 . Dict key:  3
#
# Corresponding mutation type:
# Corresponding mutation type:
# Corresponding mutation type:
# Corresponding mutation type:  [2 2] [0 0]
#  [2 1] [3 3]
#  [1 1] [0 2]
#  [0 1] [3 0]
#
# Log probabilities of common mutation type Z:
#
# Log probabilities of common mutation type Z:
#
# Log probabilities of common mutation type Z:
#
# Log probabilities of common mutation type Z:
#  [-49.71028796505811, -49.71028796505811, -49.268552831155255, -49.71032430127595, -49.700611012692875, -49.71032430127595, -49.26788199689889, -49.710155234181755, -49.710155234181755, -49.19936766339959, -26.267339668551095, -49.19936766339959]
#  [-40.7579164436034, -41.19969293021904, -41.19969293021904, -40.68892626801228, -17.768986297624156, -40.68892626801228, -41.199693786409796, -41.199693786409796, -41.04546156364864, -41.19969378975043, -41.0454745473923, -41.19969378975043]
#  [-40.641353949289794, -41.08328886128611, -41.08328886128611, -41.08333902793868, -41.083428189609634, -41.083428189609634, -41.08344073211493, -41.08344073211493, -40.641678854568475, -17.652949923361206, -40.57274677765114, -40.57274677765114]
#  [-40.09395322110208, -40.09395198300718, -40.09395322110208, -24.675907744860602, -39.91152794961014, -39.91152794961014, -39.91155854193448, -39.469520343174096, -39.91155854193448, -39.911512688414085, -39.911571312536616, -39.911571312536616]
#
# sum Z:
#
# sum Z:
#
# sum Z:
#
# sum Z:
#  3.91056337096597e-12
#  1.9187893632853462e-08
#  2.1548709149108153e-08
#  1.9203951075120483e-11
#
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:  0  are ids:  1 0  dist:  0.9999900651308726
#  1  are ids:  1 0  dist:  0.5000480287513362
#  3  are ids:  1 0  dist:  0.9999899960860544
#  2  are ids:  2 0  dist:  0.9999868416345264
#
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:  0  are ids:  2 0  dist:  0.5020832041038042
#  1  are ids:  2 0  dist:  0.5000556766516344
#  3  are ids:  2 0  dist:  3.5716228557942674e-05
#  2  are ids:  3 0  dist:  1.56325021262981e-05
#
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:  0  are ids:  2 1  dist:  0.5020832032738066
#  1  are ids:  2 1  dist:  0.9999486766275917
#  3  are ids:  2 1  dist:  3.571478144568052e-05
#  2  are ids:  3 2  dist:  1.5536028962373164e-05
#
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:  0  are ids:  3 0  dist:  0.0009021609040872777
#  1  are ids:  3 0  dist:  0.499958368107348
#  3  are ids:  3 0  dist:  0.4999548042264868
#  2  are ids:  4 0  dist:  0.012088016289448793
#
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:  0  are ids:  3 1  dist:  0.0009021584024389854
#  1  are ids:  3 1  dist:  1.9190647021358516e-05
#  3  are ids:  3 1  dist:  0.4999548037440338
#  2  are ids:  4 2  dist:  0.012087925361354288
#
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:  0  are ids:  3 2  dist:  0.49822672358735215
#  1  are ids:  3 2  dist:  4.214049104751663e-05
#  3  are ids:  3 2  dist:  0.5000570994254698
#  2  are ids:  4 3  dist:  0.9879143588530082
#
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
# Total time of position  0  are ids:  4 0  dist:  0.01190856976292378
#  1  are ids:  4 0  dist:  0.49995836780541575
#  3  are ids:  4 0  dist:  1.5006060871914709e-05
#  2  is:  0.160477876663208
#
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:  0  are ids:  4 1  dist:  0.01190856728594507
#  1  are ids:  4 1  dist:  1.9189919299852295e-05
#  3  are ids:  4 1  dist:  1.5004613645096167e-05
#
# ******
# Analysing DBC for parameters:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:  2e-05 0.3 1.0 1.0
#  0  are ids:  4 2  dist:  0.5018945415488348
#  1  are ids:  4 2  dist:  4.2139763337692586e-05
#  3  are ids:  4 2  dist:  0.9999592860709272
# Pos idx of process is:  4
#
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos:
#  Similarity. Cells with reads for pos: Process id:  95774 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
#  0  are ids:  4 3  dist:  0.9872549237729928
#  1  are ids:  4 3  dist:  0.9999899970855118
#  3  are ids:  4 3  dist:  0.5000501978809833
#
# ***********
# Position:
# Total time of position
# Total time of position
# Total time of position  4
#  0  is:  0.20948314666748047
#  1  is:  0.21871709823608398
#  3  is:  0.23408102989196777
#
# Loading read position dictionary...
#
# Loading log_ZCY position dictionary...
# 	Computing for z_ind:  0
# 	Computing for z_ind:  1
# 	Computing for z_ind:  2
# 	Computing for z_ind:  3
# 	Computing for z_ind:  4
# 	Computing for z_ind:  5
# 	Computing for z_ind:  6
# 	Computing for z_ind:  7
# 	Computing for z_ind:  8
# 	Computing for z_ind:  9
# 	Computing for z_ind:  10
#
# *****
# Plotting distance matrices...
# 	Computing for z_ind:  11
# Total time:  0.018449068069458008
#
# ***Common Z results:
#
#
# Normalized probabilities of common mutation type Z:
#  [1.40668880e-09 1.43050509e-09 2.34444226e-09 1.40675937e-09
#  1.40665145e-09 1.40665145e-09 1.12562855e-09 1.12537408e-09
#  1.13039935e-09 9.99999983e-01 1.87493978e-09 1.87493978e-09]
#
# Maximum probability:  0.9999999834670201 . Dict key:  9
#
# Corresponding mutation type:  [3 1] [0 2]
#
# Log probabilities of common mutation type Z:
#  [-47.72964866503542, -47.71285964299041, -47.2188397032845, -47.72959849649559, -47.72967521697812, -47.72967521697812, -47.95254564644442, -47.95277173982675, -47.94831625704173, -27.347621415931275, -47.442310692592926, -47.442310692592926]
#
# sum Z:
#  1.3276357337198352e-12
#
#  Similarity. Cells with reads for pos:  4  are ids:  1 0  dist:  0.5000149525988195
#
#  Similarity. Cells with reads for pos:  4  are ids:  2 0  dist:  0.9999803172253624
#
#  Similarity. Cells with reads for pos:  4  are ids:  2 1  dist:  0.5000148454501201
#
#  Similarity. Cells with reads for pos:  4  are ids:  3 0  dist:  1.5017799936581305e-05
#
#  Similarity. Cells with reads for pos:  4  are ids:  3 1  dist:  0.4999900577893195
#
#  Similarity. Cells with reads for pos:  4  are ids:  3 2  dist:  1.469634193427224e-05
#
#  Similarity. Cells with reads for pos:  4  are ids:  4 0  dist:  9.438056762338787e-05
#
#  Similarity. Cells with reads for pos:  4  are ids:  4 1  dist:  0.5000165120491848
#
#  Similarity. Cells with reads for pos:  4  are ids:  4 2  dist:  9.405913342898738e-05
#
#  Similarity. Cells with reads for pos:  4  are ids:  4 3  dist:  0.9999106325940454
#
# Total time of position  4  is:  0.1192779541015625

# %% [markdown]
# ### Combine distance between cells

# %%
# %run analyse_dbc_combine.py ../data/2020_07_09/  --pos_range_max 0 --data_type synthetic --output_dir ../results/2020_07_09_results/ --pos_range_min 0
# Out:
# *****
# Loading dictionaries
#
# Total time of loading dictionaries:  0.0044481754302978516
#
# *****
# Combining multiple sites
#
# *****
# Combining multiple sites
#
# Using  1  positions
#
# Using  2  positions
#
# Using  3  positions
#
# Using  4  positions
#
# Using  5  positions
#
# *****
# Analysis:
# 	Total number: 	 5
# 	Heterozygous: 	 5 . 	% 100.0
# 	Correct heterozygous: 	 0 . 	% 0.0
# 	Homozygous: 	 0 . 	% 0.0
# 	(Skipped positions:  [] )
#
# Total time of combining multiple sites:  5.861721038818359
#
# Total time of combining sites:  5.862156867980957

# %% [markdown]
# ### Reconstruct lineage tree

# %%
# %run lineage_trees.py ../results/2020_07_09_results/ --data_type synthetic
# Out:
# Trees of case:  selected
#
#
# 	Case:  selected .	Tree with bulk as a node:
#
# /--------------------------------------------------------------------------- V2
# |
# +                                                        /------------------ V0
# |                  /-------------------------------------+
# |                  |                                     \------------------ V1
# \------------------+
#                    |                  /------------------------------------- V5
#                    \------------------+
#                                       |                  /------------------ V3
#                                       \------------------+
#                                                          \------------------ V4
#
#
# [&R] (V2:1.3877787807814457e-17,((V0:0.0,V1:0.0):0.40000000000000013,(V5:-5.551115123125783e-17,(V3:0.0,V4:0.0):0.6000000000000001):-1.6653345369377348e-16):1.3877787807814457e-17);
#
#
# 	Case:  selected .	Tree with bulk as a root:
#
#                                                   /------------------------- V3
# /-------------------------------------------------+
# |                                                 \------------------------- V4
# +
# |                                                 /------------------------- V0
# |                        /------------------------+
# \------------------------+                        \------------------------- V1
#                          |
#                          \-------------------------------------------------- V2
#
#
# [&R] ((V3:0.0,V4:0.0):0.6000000000000001,((V0:0.0,V1:0.0):0.40000000000000013,V2:2.7755575615628914e-17):-1.6653345369377348e-16)V5;
#
#
# 	Case:  selected .	Tree with bulk, midpoint rooted:
#
#                                                   /------------------------- V3
# /-------------------------------------------------+
# |                                                 \------------------------- V4
# +
# |                                                 /------------------------- V0
# |                        /------------------------+
# \------------------------+                        \------------------------- V1
#                          |
#                          \-------------------------------------------------- V2
#
#
# [&R] ((V3:0.0,V4:0.0):0.5,((V0:0.0,V1:0.0):0.40000000000000013,V2:2.7755575615628914e-17):0.09999999999999992);
#
#
# 	Case:  selected .	Tree without bulk:
#
#                                                   /------------------------- V0
# /-------------------------------------------------+
# |                                                 \------------------------- V1
# +
# |                        /-------------------------------------------------- V2
# \------------------------+
#                          |                        /------------------------- V4
#                          \------------------------+
#                                                   \------------------------- V3
#
#
# [&R] ((V0:0.0,V1:0.0):0.19999999999999998,(V2:-1.1102230246251565e-16,(V4:0.0,V3:0.0):0.6000000000000001):0.19999999999999998);
#
#
# 	Case:  selected .	Tree without bulk, midpoint rooted:
#
#                                                   /------------------------- V4
# /-------------------------------------------------+
# |                                                 \------------------------- V3
# +
# |                        /-------------------------------------------------- V2
# \------------------------+
#                          |                        /------------------------- V0
#                          \------------------------+
#                                                   \------------------------- V1
#
#
# [&R] ((V4:0.0,V3:0.0):0.5,(V2:-1.1102230246251565e-16,(V0:0.0,V1:0.0):0.39999999999999997):0.10000000000000009);
#
#
# Trees of case:  inferred
#
#
# 	Case:  inferred .	Tree with bulk as a node:
#
#                                                   /------------------------- V2
# /-------------------------------------------------+
# |                                                 \------------------------- V5
# |
# +                                                 /------------------------- V3
# |                        /------------------------+
# |                        |                        \------------------------- V4
# \------------------------+
#                          |                        /------------------------- V0
#                          \------------------------+
#                                                   \------------------------- V1
#
#
# [&R] ((V2:0.04664885417499988,V5:0.053784193925000126):0.06894537630625003,((V3:0.050710362600000045,V4:0.05426561539999995):0.4588116947624999,(V0:0.09361112120833343,V1:0.15637811819166658):0.19290858756250012):0.06894537630625003);
#
#
# 	Case:  inferred .	Tree with bulk as a root:
#
# /--------------------------------------------------------------------------- V2
# |
# +                                                 /------------------------- V3
# |                        /------------------------+
# |                        |                        \------------------------- V4
# \------------------------+
#                          |                        /------------------------- V0
#                          \------------------------+
#                                                   \------------------------- V1
#
#
# [&R] (V2:0.04664885417499988,((V3:0.050710362600000045,V4:0.05426561539999995):0.4588116947624999,(V0:0.09361112120833343,V1:0.15637811819166658):0.19290858756250012):0.13789075261250006)V5;
#
#
# 	Case:  inferred .	Tree with bulk, midpoint rooted:
#
#                                                   /------------------------- V3
# /-------------------------------------------------+
# |                                                 \------------------------- V4
# +
# |                                                 /------------------------- V0
# |                        /------------------------+
# \------------------------+                        \------------------------- V1
#                          |
#                          \-------------------------------------------------- V2
#
#
# [&R] ((V3:0.050710362600000045,V4:0.05426561539999995):0.3769163925583333,((V0:0.09361112120833343,V1:0.15637811819166658):0.19290858756250012,V2:0.18453960678749992):0.08189530220416658);
#
#
# 	Case:  inferred .	Tree without bulk:
#
#                                                   /------------------------- V4
# /-------------------------------------------------+
# |                                                 \------------------------- V3
# +
# |                        /-------------------------------------------------- V2
# \------------------------+
#                          |                        /------------------------- V0
#                          \------------------------+
#                                                   \------------------------- V1
#
#
# [&R] ((V4:0.07156110758333327,V3:0.03341487041666673):0.25586449470625,(V2:0.18453960678749987,(V0:0.10917072268750003,V1:0.14081851671249998):0.13999129291250018):0.25586449470625);
#
#
# 	Case:  inferred .	Tree without bulk, midpoint rooted:
#
#                          /-------------------------------------------------- V2
# /------------------------+
# |                        |                        /------------------------- V0
# |                        \------------------------+
# +                                                 \------------------------- V1
# |
# |                                                 /------------------------- V4
# \-------------------------------------------------+
#                                                   \------------------------- V3
#
#
# [&R] ((V2:0.18453960678749987,(V0:0.10917072268750003,V1:0.14081851671249998):0.13999129291250018):0.15124014368541655,(V4:0.07156110758333327,V3:0.03341487041666673):0.36048884572708345);
#
#
#
# Comparison Results for inferred and selected for _w_bulk_root.tre
# R-F:  2
# Normalised R-F:  0.125
# Weighted R-F:  0.8877845418625003
# Normalised Weighted R-F:  0.05548653386640627
# Euc:  0.350348999778636
#
#
# Comparison Results for inferred and selected for _w_bulk_root_midpoint.tre
# R-F:  0
# Normalised R-F:  0.0
# Weighted R-F:  0.8877845418624999
# Normalised Weighted R-F:  0.05548653386640624
# Euc:  0.36214987206209104
#
#
# Comparison Results for inferred and selected for _wo_bulk.tre
# R-F:  2
# Normalised R-F:  0.125
# Weighted R-F:  1.399513531275
# Normalised Weighted R-F:  0.0874695957046875
# Euc:  0.5473001407631862
#
#
# Comparison Results for inferred and selected for _wo_bulk_midpoint.tre
# R-F:  0
# Normalised R-F:  0.0
# Weighted R-F:  0.9902648292333328
# Normalised Weighted R-F:  0.0618915518270833
# Euc:  0.40216160402355383
