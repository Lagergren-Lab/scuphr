# %% [markdown]
# # 04. Lineage Trees
#
# This notebook reconstructs lineage trees from distance matrix and compares RF distance to the true tree.
#
# Steps:
# * Lineage trees (analyse_dbc.py)

# %%
# %run lineage_trees.py --help
# Out:
# usage: lineage_trees.py [-h] [--data_type DATA_TYPE] output_dir
#
# Distance between cells computation.
#
# positional arguments:
#   output_dir            Specify the results directory.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --data_type DATA_TYPE
#                         Specify the data type. Default: real

# %%
# %run lineage_trees.py "../results/2020_07_09_1/" --data_type "synthetic"
# Out:
# Trees of case:  selected
#
#
# 	Case:  selected .	Tree with bulk as a node:
#
# /--------------------------------------------------------------------------- V5
# |
# +                                                        /------------------ V0
# |                  /-------------------------------------+
# |                  |                                     \------------------ V1
# \------------------+
#                    |                  /------------------------------------- V2
#                    \------------------+
#                                       |                  /------------------ V4
#                                       \------------------+
#                                                          \------------------ V3
#
#
# [&R] (V5:1.3877787807814457e-17,((V0:0.0,V1:0.0):0.40000000000000013,(V2:-5.551115123125783e-17,(V4:0.0,V3:0.0):0.6000000000000001):-1.6653345369377348e-16):1.3877787807814457e-17);
#
#
# ...
