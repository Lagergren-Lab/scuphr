# %% [markdown]
# # 03. Distance Between Cells and Combine Results
#
# This notebook calculates the distance between cells (DBC) for each pair of sites. Then, it combines the results.
#
# Steps:
# * Distance between cells analysis (analyse_dbc.py)
# * Combine  results (analyse_dbc_combine.py)

# %% [markdown]
# ### Analyse distance between cells

# %%
# %run analyse_dbc.py --help
# Out:
# usage: analyse_dbc.py [-h] [--a_g A_G] [--b_g B_G] [--data_type DATA_TYPE]
#                       [--output_dir OUTPUT_DIR] [--p_ado P_ADO] [--p_ae P_AE]
#                       [--pos_range_min POS_RANGE_MIN]
#                       [--pos_range_max POS_RANGE_MAX]
#                       [--print_status PRINT_STATUS] [--seed_val SEED_VAL]
#                       global_dir
#
# Distance between cells computation.
#
# positional arguments:
#   global_dir            Specify the data directory.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --a_g A_G             Specify the alpha prior of mutation probability.
#                         Default: 1
#   --b_g B_G             Specify the beta prior of mutation probability.
#                         Default: 1
#   --data_type DATA_TYPE
#                         Specify the data type. Default: real
#   --output_dir OUTPUT_DIR
#                         Specify the output directory.
# ...

# %%
# %run analyse_dbc.py "../data/2020_07_09_1/" --p_ado 0.2 --p_ae 0.001 --data_type "synthetic" --output_dir "../results/2020_07_09_1/" --a_g 1 --b_g 1 --print_status 0
# Out:
# Read probability directory is created
# Output directory is created
# Matrix directory is created
# Common Z status directory is created
# Figures directory is created
#
# *****
# Load the dataset and read probabilities...
#
# The dataset is loaded. Number of cells: 5, number of position pairs: 5
#
# Position range: [ 0 ,  5 )
# Number of positions in range:  5
#
# *****
# Calculating real distances...
#
# *****
# Calculating real distances finished...
#
# ******
# Analysing Real DBC
# ******
# Analysing Real DBC
# ******
# Analysing Real DBC
# ******
# Analysing Real DBC
#
#
#
# Pos idx of process is:  0
# Pos idx of process is:  1
# Pos idx of process is:  2
# Pos idx of process is:  3
# Process id:  25987 . Uname:  posix.uname_result(sysname='Darwin', nodename='Hazals-MBP.lan', release='19.2.0', version='Darwin Kernel Version 19.2.0: Sat Nov  9 03:47:04 PST 2019; root:xnu-6153.61.1~20/RELEASE_X86_64', machine='x86_64')
# ...

# %% [markdown]
# ### Combine distance between cells

# %%
# %run analyse_dbc_combine.py --help
# Out:
# usage: analyse_dbc_combine.py [-h] [--data_type DATA_TYPE]
#                               [--pos_range_min POS_RANGE_MIN]
#                               [--pos_range_max POS_RANGE_MAX]
#                               [--output_dir OUTPUT_DIR]
#                               global_dir
#
# Distance between cells computation.
#
# positional arguments:
#   global_dir            Specify the data directory.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --data_type DATA_TYPE
#                         Specify the data type. Default: real
#   --pos_range_min POS_RANGE_MIN
#                         Specify the position range (min value). Default: 0
#   --pos_range_max POS_RANGE_MAX
#                         Specify the position range (max value). Default:
#   --output_dir OUTPUT_DIR
#                         Specify the output directory.

# %%
# %run analyse_dbc_combine.py "../data/2020_07_09_1/" --data_type "synthetic" --output_dir "../results/2020_07_09_1/"
# Out:
# Combined figures directory is created
#
# *****
# Loading dictionaries
#
# Total time of loading dictionaries:  0.004057168960571289
#
# *****
# Combining multiple sites
#
# *****
# Combining multiple sites
#
# Using  1  positions
#
# Using  2  positions
#
# Using  3  positions
#
# Using  4  positions
#
# Using  5  positions
#
# *****
# Analysis:
# 	Total number: 	 5
# 	Heterozygous: 	 5 . 	% 100.0
# 	Correct heterozygous: 	 5 . 	% 100.0
# 	Homozygous: 	 0 . 	% 0.0
# 	(Skipped positions:  [] )
#
# Total time of combining multiple sites:  6.512618064880371
#
# Total time of combining sites:  6.513077020645142
